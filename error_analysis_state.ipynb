# %%
# %matplotlib notebook
from matplotlib import pyplot as plt
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !python3 "/content/drive/My Drive/Evolution.AI---RN/more_clevr_state.py"
# Out:
# 2020
# building test datasets...
# building train datasets...
# building validation datasets...
# saving datasets...
# tcmalloc: large alloc 1155784704 bytes == 0xe4916000 @  0x7f3c15e482a4 0x591f47 0x4dd7c7 0x4e2be0 0x4e222a 0x4e0ea8 0x4e263b 0x4e2209 0x4e23cb 0x4e1fcb 0x4e34a6 0x454438 0x50a5aa 0x50c1f4 0x507f24 0x50b053 0x634dd2 0x634e87 0x63863f 0x6391e1 0x4b0dc0 0x7f3c15a44b97 0x5b26fa
# tcmalloc: large alloc 1733681152 bytes == 0x129754000 @  0x7f3c15e482a4 0x591f47 0x4dd7c7 0x4e2be0 0x4e222a 0x4e0ea8 0x4e263b 0x4e2209 0x4e23f3 0x4e1fcb 0x4e34a6 0x454438 0x50a5aa 0x50c1f4 0x507f24 0x50b053 0x634dd2 0x634e87 0x63863f 0x6391e1 0x4b0dc0 0x7f3c15a44b97 0x5b26fa
# datasets saved at ./data/more-clevr_state.pickle

# %%
# !python3 "/content/drive/My Drive/Evolution.AI---RN/error_analysis_state.py"
# Out:
# 2020-09-07 17:33:49.575272: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# loading data...
# processing data...
# 588
# 50
# full saved

# %%
import numpy as np
from matplotlib import pyplot as plt
import cv2

# %%
# name = 'wrong_samples_noH.npy'
# path = F"/content/drive/My Drive/Evolution.AI---RN/{name}"#Gdrive path
# with open(path, 'rb') as f:
#     wrong_samples_noH = np.load(f,allow_pickle=True)

name = 'wrong_samples_Q4noGT.npy'
path = F"/content/drive/My Drive/Evolution.AI---RN/{name}"#Gdrive path
with open(path, 'rb') as f:
    wrong_samples_full = np.load(f,allow_pickle=True)
colors = ['red','green','blue','orange','gray','yellow']

# %%
# samples_noH = []
# for batch in wrong_samples_noH:
#   n = np.shape(batch[2])[0]
#   for sample in range(n):
#     img = batch[0][sample]
#     qst = batch[1][sample]
#     ans = batch[2][sample]
#     samples_noH.append([img,qst,ans])
# print(np.shape(samples_noH))
samples_full = []
for batch in wrong_samples_full:
  n = np.shape(batch[2])[0]
  for sample in range(n):
    img = batch[0][sample]
    qst = batch[1][sample]
    ans = batch[2][sample]
    states = batch[3][sample]
    samples_full.append([img,qst,ans,states])
print(np.shape(samples_full))
# Out:
# (369, 4)

# %%
qst =np.zeros(19)
ans = np.zeros(2)
for sample in samples_full:
  x = x+sample[1]
  if sample[2] == 2:
    ans += [1,0]
  else:
    ans += [0,1]

# %%
ans
# Out:
# array([168., 201.])

# %%
def plot_fig(samples):
  num_of_img = np.shape(samples)[0]
  for i in range(num_of_img):
    img = np.einsum('abc->bca', samples[i][0])
    plt.figure()
    plt.imshow(img[:,:,::-1])#BGR to RGB
    object1 = colors[np.where(samples[i][1])[0][0]]
    #object2 = colors[np.where(samples[i][1])[0][1]-6]
    if samples[i][2] == 2:
      ans = 'rec'
    else:
      ans = 'circle'
    plt.title('color: '+ object1+ ' predicted closest is: '+ans)

# %%
# common_error = []
# noH_error = []
# for sample in samples_noH:
#   if sample in samples_full:
#     common_error.append(sample)
#   else:
#     noH_error.append(sample)

# %%
plot_fig(samples_full)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
