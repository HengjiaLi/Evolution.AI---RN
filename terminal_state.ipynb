# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
# from google.colab import auth
# auth.authenticate_user()
# from oauth2client.client import GoogleCredentials
# creds = GoogleCredentials.get_application_default()
# import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
# vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}

# %%
# !mkdir -p drive
# !google-drive-ocamlfuse drive

# %%
# %matplotlib notebook
from matplotlib import pyplot as plt

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
#!python3 /content/drive/Evolution.AI---RN/more_clevr.py
# !python3 "/content/drive/My Drive/Evolution.AI---RN/more_clevr_state.py"
# Out:
# 2020
# building test datasets...
# building train datasets...
# building validation datasets...
# saving datasets...
# tcmalloc: large alloc 1155784704 bytes == 0xe3268000 @  0x7f39b59862a4 0x591f47 0x4dd7c7 0x4e2be0 0x4e222a 0x4e0ea8 0x4e263b 0x4e2209 0x4e23cb 0x4e1fcb 0x4e34a6 0x454438 0x50a5aa 0x50c1f4 0x507f24 0x50b053 0x634dd2 0x634e87 0x63863f 0x6391e1 0x4b0dc0 0x7f39b5582b97 0x5b26fa
# tcmalloc: large alloc 1733681152 bytes == 0x1280a6000 @  0x7f39b59862a4 0x591f47 0x4dd7c7 0x4e2be0 0x4e222a 0x4e0ea8 0x4e263b 0x4e2209 0x4e23f3 0x4e1fcb 0x4e34a6 0x454438 0x50a5aa 0x50c1f4 0x507f24 0x50b053 0x634dd2 0x634e87 0x63863f 0x6391e1 0x4b0dc0 0x7f39b5582b97 0x5b26fa
# datasets saved at ./data/more-clevr_state.pickle

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')

# %%
# !python3 "/content/drive/My Drive/Evolution.AI---RN/main_state.py"
#%run "/content/drive/My Drive/Evolution.AI---RN/main_state.py"
# Out:
# 2020-09-12 18:43:50.527972: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# loading data...
# processing data...
# Training RN (binary) model...
# Train Epoch: 1 [0/294000 (0%)] Relations accuracy: 8% | Non-relations accuracy: 12%
# Train Epoch: 1 [1000/294000 (0%)] Relations accuracy: 22% | Non-relations accuracy: 24%
# Train Epoch: 1 [2000/294000 (1%)] Relations accuracy: 26% | Non-relations accuracy: 40%
# Train Epoch: 1 [3000/294000 (1%)] Relations accuracy: 30% | Non-relations accuracy: 42%
# Train Epoch: 1 [4000/294000 (1%)] Relations accuracy: 42% | Non-relations accuracy: 44%
# Train Epoch: 1 [5000/294000 (2%)] Relations accuracy: 46% | Non-relations accuracy: 40%
# Train Epoch: 1 [6000/294000 (2%)] Relations accuracy: 42% | Non-relations accuracy: 48%
# Train Epoch: 1 [7000/294000 (2%)] Relations accuracy: 46% | Non-relations accuracy: 56%
# ...

# %%
# !python3 "/content/drive/My Drive/Evolution.AI---RN/eval_on_more_clevr_state.py"
# Out:
# 2020-09-12 18:50:27.264048: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# loading data...
# processing data...
#
#  Test set: Unary accuracy (shape of object): 100%
#
#
#  Test set: Unary accuracy (query vertical position): 51%
#
#
#  Test set: Unary accuracy (query horizontal position->yes/no): 51%
#
# (4, 588)
#
#  Test set: Binary accuracy (closest-to): 67%
#
# (4, 639)
#
#  Test set: Binary accuracy (furthest-to): 67%
#
# (4, 582)
#
#  Test set: Binary accuracy (count same color): 100%
#
#
#  Test set: Binary accuracy (above object): 58%
#
#
#  Test set: Binary accuracy (left to object): 62%

# %%
# !ls "/content/drive/My Drive/Evolution.AI---RN"
# Out:
#  coco_utils.py			    model_sincomplex.py
# 'Copy of dataset_breakdown.ipynb'   model_sin.py
#  data				    model_sin_relative.py
#  dataset_breakdown.ipynb	    more_clevr.py
#  engine.py			    more_clevr_state.py
#  environment_linux.yml		   'PE Demo.ipynb'
#  environment_mac.yml		    __pycache__
#  error_analysis.ipynb		    pytorchtools.py
#  error_analysis.py		    README.md
#  error_analysis_state.ipynb	    run.sh
#  error_analysis_state.py	    sim_statenoGT.pth
#  eval_on_more_clevr.py		    sim_state.pth
#  eval_on_more_clevr_state.py	    sin_relative.pth
#  eval_on_sort_of_clevr.py	    sort_of_clevr_generator.py
#  Faster_RCNN.ipynb		    state_dataset_analysis.ipynb
#  figs				    terminal.ipynb
#  License.md			    terminal_rcnn.ipynb
#  main.py			    terminal_state.ipynb
#  main_rcnn.py			    train_curve.png
#  main_state.py			    train_curve_repPadLR.png
#  model_rcnn.py			    train_curve_state.png
#  model_saved			    translator.py
#  model_simnoH.py		    utils.py
# ...
