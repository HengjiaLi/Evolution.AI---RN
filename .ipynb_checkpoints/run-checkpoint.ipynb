# %%
# %matplotlib notebook
from matplotlib import pyplot as plt

# %%
# mount script on G-drive
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Generate dataset
# !python3 "/content/drive/My Drive/Evolution.AI---RN/more_clevr.py"
# Out:
# directory ./data already exists
# building test datasets...
# building train datasets...
# building validation datasets...
# saving datasets...
# tcmalloc: large alloc 1143668736 bytes == 0xe2eca000 @  0x7f099c4702a4 0x591f47 0x4dd7c7 0x4e2be0 0x4e222a 0x4e0ea8 0x4e263b 0x4e1fcb 0x4e23cb 0x4e1fcb 0x4e34a6 0x454438 0x50a5aa 0x50c1f4 0x507f24 0x50b053 0x634dd2 0x634e87 0x63863f 0x6391e1 0x4b0dc0 0x7f099c06cb97 0x5b26fa
# tcmalloc: large alloc 1715503104 bytes == 0x12717a000 @  0x7f099c4702a4 0x591f47 0x4dd7c7 0x4e2be0 0x4e222a 0x4e0ea8 0x4e263b 0x4e1fcb 0x4e23f3 0x4e1fcb 0x4e34a6 0x454438 0x50a5aa 0x50c1f4 0x507f24 0x50b053 0x634dd2 0x634e87 0x63863f 0x6391e1 0x4b0dc0 0x7f099c06cb97 0x5b26fa
# datasets saved at ./data/more-clevr.pickle

# %%
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')

# %%
# Train model
#!python3 "/content/drive/My Drive/Evolution.AI---RN/main.py"
# %run "/content/drive/My Drive/Evolution.AI---RN/main.py"
# Out:
# Streaming output truncated to the last 5000 lines.
# Train Epoch: 9 [119000/294000 (40%)] Relations accuracy: 90% | Non-relations accuracy: 100%
# Train Epoch: 9 [120000/294000 (41%)] Relations accuracy: 90% | Non-relations accuracy: 98%
# Train Epoch: 9 [121000/294000 (41%)] Relations accuracy: 76% | Non-relations accuracy: 98%
# Train Epoch: 9 [122000/294000 (41%)] Relations accuracy: 82% | Non-relations accuracy: 96%
# Train Epoch: 9 [123000/294000 (42%)] Relations accuracy: 80% | Non-relations accuracy: 100%
# Train Epoch: 9 [124000/294000 (42%)] Relations accuracy: 82% | Non-relations accuracy: 100%
# Train Epoch: 9 [125000/294000 (43%)] Relations accuracy: 84% | Non-relations accuracy: 100%
# Train Epoch: 9 [126000/294000 (43%)] Relations accuracy: 86% | Non-relations accuracy: 98%
# Train Epoch: 9 [127000/294000 (43%)] Relations accuracy: 74% | Non-relations accuracy: 100%
# Train Epoch: 9 [128000/294000 (44%)] Relations accuracy: 92% | Non-relations accuracy: 100%
# ...

# %%
# Evaluate model
# !python3 "/content/drive/My Drive/Evolution.AI---RN/eval_on_more_clevr.py"
# Out:
# 2020-09-16 18:02:44.166862: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# normal sin summed
# normal sin summed
# loading data...
# processing data...
#
#  Test set: Unary accuracy (shape of object): 100%
#
#
#  Test set: Unary accuracy (query vertical position): 99%
#
#
#  Test set: Unary accuracy (query horizontal position->yes/no): 100%
#
#
#  Test set: Binary accuracy (closest-to): 84%
#
#
#  Test set: Binary accuracy (furthest-to): 79%
#
#
#  Test set: Binary accuracy (count same color): 100%
#
#
#  Test set: Binary accuracy (above object): 97%
#
#
#  Test set: Binary accuracy (left to object): 97%
